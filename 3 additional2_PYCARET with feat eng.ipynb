# %%
# %load_ext lab_black

# %%
import functions as myFunc

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
pd.set_option("float_format", "{:.2f}".format)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv(
    r"C:\Users\jonyt\Python\3 module\sprint 2\project\healthcare-dataset-stroke-data.csv"
)
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male 67.00             0              1          Yes
# 1  51676  Female 61.00             0              0          Yes
# 2  31112    Male 80.00             0              1          Yes
# 3  60182  Female 49.00             0              0          Yes
# 4   1665  Female 79.00             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69 36.60  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92 32.50     never smoked
# 3        Private          Urban             171.23 34.40           smokes
# 4  Self-employed          Rural             174.12 24.00     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.shape
# Out:
# (5110, 12)

# %%
from pycaret.classification import *

# %%
clf1 = setup(
    data=df, target="stroke", polynomial_features=True, fix_imbalance=True, n_jobs=1
)
# Out:
# <style type="text/css">
# #T_f56f4_row11_col1, #T_f56f4_row17_col1, #T_f56f4_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f56f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f56f4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f56f4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f56f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f56f4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f56f4_row0_col1" class="data row0 col1" >6546</td>
#     </tr>
#     <tr>
#       <th id="T_f56f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f56f4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f56f4_row1_col1" class="data row1 col1" >stroke</td>
#     </tr>
#     <tr>
# ...

# %%
# Engineerd features TRAINING set
X_train_engineerd = get_config("X_train_transformed")
y_train_engineerd = get_config("y_train")
X_train_engineerd.shape, y_train_engineerd.shape
# Out:
# ((6806, 230), (3577,))

# %%
# Engineerd features TESTING set
X_test_engineerd = get_config("X_test_transformed")
y_test_engineerd = get_config("y_test")
X_test_engineerd.shape, y_test_engineerd.shape
# Out:
# ((1533, 230), (1533,))

# %%
y_train_engineerd.value_counts()
# Out:
# 0    3403
# 1     174
# Name: stroke, dtype: int64

# %% [markdown]
# Possible variables are: ['idx', 'pipeline', 'test', 'logging_param', 'X_train', 'fold_generator', 'dataset_transformed', 'target_param', '_available_plots', 'X_test', 'gpu_param', 'data', 'fold_shuffle_param', 'y_train_transformed', 'X_transformed', 'y_train', 'fold_groups_param', 'train', 'memory', 'y_transformed', 'y', 'X_train_transformed', 'test_transformed', 'exp_name_log', 'n_jobs_param', 'variable_and_property_keys', 'variables', 'fix_imbalance', 'dataset', 'is_multiclass', 'seed', 'X', 'train_transformed', 'y_test_transformed', 'exp_id', 'log_plots_param', 'gpu_n_jobs_param', 'X_test_transformed', 'y_test', 'USI', 'html_param', '_ml_usecase']

# %%
best_model = compare_models(sort="F1", fold=5, errors="raise")
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             22:02:09
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_cddb0 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# Additional conclusion:
#
# using automated feature engineering with PyCaret results are nearly the same.
